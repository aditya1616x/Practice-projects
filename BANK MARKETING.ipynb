# %%
import pandas as pd

# Load the datasets
train_df = pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Bank%20Marketing/termdeposit_train.csv")
test_df = pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Bank%20Marketing/termdeposit_test.csv")

# Check the first few rows of the training data
print(train_df.head())

# Check for missing values
print(train_df.isnull().sum())

# Encode categorical variables
train_df = pd.get_dummies(train_df, columns=['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome'], drop_first=True)

# Split the data into features and target variable
X_train = train_df.drop(['ID', 'subscribed'], axis=1)
y_train = train_df['subscribed']

# Apply the same preprocessing to the test data
test_df = pd.get_dummies(test_df, columns=['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome'], drop_first=True)
X_test = test_df.drop('ID', axis=1)
# Out:
#       ID  age         job   marital  education default  balance housing loan  \
# 0  26110   56      admin.   married    unknown      no     1933      no   no
# 1  40576   31     unknown   married  secondary      no        3      no   no
# 2  15320   27    services   married  secondary      no      891     yes   no
# 3  43962   57  management  divorced   tertiary      no     3287      no   no
# 4  29842   31  technician   married  secondary      no      119     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  telephone   19   nov        44         2     -1         0  unknown
# 1   cellular   20   jul        91         2     -1         0  unknown
# 2   cellular   18   jul       240         1     -1         0  unknown
# 3   cellular   22   jun       867         1     84         3  success
# 4   cellular    4   feb       380         1     -1         0  unknown
#
#   subscribed
# 0         no
# 1         no
# 2         no
# 3        yes
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize distribution of target variable
sns.countplot(x='subscribed', data=train_df)
plt.show()

# Explore relationship between features and target variable
plt.figure(figsize=(12, 6))
sns.boxplot(x='subscribed', y='age', data=train_df)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# Initialize the model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

# Evaluate the model using cross-validation
cv_scores = cross_val_score(rf_model, X_train, y_train, cv=5, scoring='accuracy')
print("Cross-validation scores:", cv_scores)
print("Mean CV accuracy:", cv_scores.mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20004\2193224166.py in ?()
#       4 # Initialize the model
#       5 rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
#       6
#       7 # Train the model
# ----> 8 rf_model.fit(X_train, y_train)
#       9
#      10 # Evaluate the model using cross-validation
#      11 cv_scores = cross_val_score(rf_model, X_train, y_train, cv=5, scoring='accuracy')
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
from sklearn.metrics import classification_report

# Make predictions on the training data
train_predictions = rf_model.predict(X_train)

# Print classification report
print(classification_report(y_train, train_predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20004\2060371854.py in ?()
#       1 from sklearn.metrics import classification_report
#       2
#       3 # Make predictions on the training data
# ----> 4 train_predictions = rf_model.predict(X_train)
#       5
#       6 # Print classification report
#       7 print(classification_report(y_train, train_predictions))
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py in ?(self, X)
#     819         -------
#     820         y : ndarray of shape (n_samples,) or (n_samples, n_outputs)
#     821             The predicted classes.
#     822         """
# --> 823         proba = self.predict_proba(X)
#     824
#     825         if self.n_outputs_ == 1:
#     826             return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# ...

# %%
from sklearn.model_selection import GridSearchCV

# Define the grid of hyperparameters to search
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Initialize the grid search
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, scoring='accuracy', verbose=2)

# Perform the grid search
grid_search.fit(X_train, y_train)

# Get the best parameters
print("Best parameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.0s
# ...

# %%
# Make predictions on the test data
test_predictions = grid_search.predict(X_test)

# Prepare submission file
submission_df = pd.DataFrame({'ID': test_df['ID'], 'subscribed': test_predictions})

# Save submission file
submission_df.to_csv('termdeposit_predictions.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Make predictions on the test data
# ----> 2 test_predictions = grid_search.predict(X_test)
#       4 # Prepare submission file
#       5 submission_df = pd.DataFrame({'ID': test_df['ID'], 'subscribed': test_predictions})
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:518, in BaseSearchCV.predict(self, X)
#     499 @available_if(_estimator_has("predict"))
#     500 def predict(self, X):
#     501     """Call predict on the estimator with the best found parameters.
#     502
#     503     Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     516         the best found parameters.
#     517     """
# --> 518     check_is_fitted(self)
#     519     return self.best_estimator_.predict(X)
#
# ...
